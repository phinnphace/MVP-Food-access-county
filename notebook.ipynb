# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
print("Hello World!")
import pandas as pd
import requests
from time import sleep

    fips_list = [
   "05007", "08031", "12085", "13025", "20107", "56031", "05007", "08031", "12085"
    "56031",  "05007", "08031", "12085", "13025", "13195", "16019", "17019", "17119", "18159",
    "21049", "21185", "21209", "22031", "26021", "26075", "28035", "28163", "35045", "35057",
    "36059", "40031", "42049", "48473", "49057", "51710", "51770", "54029", "55039", "72121",
    "72129", "12017", "09180", "17115", "01101", "55087", "08043", "12063", "12107", "12123",
    "13039", "13055", "13129", "13261", "18065", "18085", "18093", "18103", "21155", "21177",
    "26023", "28027", "28109", "30081", "31067", "33013", "35035", "37171", "37083", "39143",
    "42089", "45025", "45029", "48163", "48239", "48293", "51678", "54025", "48213", "56031",
    "53039", "49055", "48507", "48399", "48389", "46041", "46039", "46031", "40085", "39125",
    "38041", "37185", "37009", "31075", "30069", "29033", "28159", "28039", "28017", "21165",
    "21095", "16071", "13265", "13291", "05083", "02068", "01019", "05107", "48327", "54101",
    fips_list = ] [

    # ... (rest of your FIPS) ...
   api_key = "dbdcdd0fa6b4af8eafa96de76eb639f46a6d2473"  # use your real key


results = []


for fips in fips_list:
    state = fips[:2]
    county = fips[2:]
    url = f"https://api.census.gov/data/2021/acs/acs5/subject?get=NAME,S1701_C03_001E&for=county:{county}&in=state:{state}&key={dbdcdd0fa6b4af8eafa96de76eb639f46a6d2473}"
    try:
        r = requests.get(url)
        data = r.json()
        row = data[1]
        results.append({
            "FIPS": fips,
            "NAME": row[0],
            "percent_poverty": row[1]
        })
    except Exception as e:
        print(f"Failed for {fips}: {e}")
    sleep(0.5)  # Be nice to the API

df = pd.DataFrame(results)
df.to_csv("county_poverty_scores.csv", index=False)
# Out:
#   Cell In[2], line 6
#     fips_list = [
#     ^
# IndentationError: unexpected indent
